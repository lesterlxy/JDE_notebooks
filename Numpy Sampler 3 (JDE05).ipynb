# %%
import numpy as np

# %%
age = [18, 19, 20]
height = [1.6, 1.7, 1.8]

# %%
x = np.array([age, height])
x
# Out:
# array([[18. , 19. , 20. ],
#        [ 1.6,  1.7,  1.8]])

# %%
x = np.array([age, height]).T
x
# Out:
# array([[18. ,  1.6],
#        [19. ,  1.7],
#        [20. ,  1.8]])

# %%
x.ndim
# Out:
# 2

# %%
x.shape
# Out:
# (3, 2)

# %%
import pandas as pd

df = pd.DataFrame(x, columns=["age", "height"])
df
# Out:
#     age  height
# 0  18.0     1.6
# 1  19.0     1.7
# 2  20.0     1.8

# %% [markdown]
# #### Ref: https://scikit-image.org/skimage-tutorials/lectures/00_images_are_arrays.html

# %% [markdown]
# #### A grayscale image is represented as a 2D array (x,y)

# %%
import matplotlib.pyplot as plt
from skimage import data

coins = data.coins()

print("Type:", type(coins))
print("dtype:", coins.dtype)
print("shape:", coins.shape)

plt.imshow(coins, cmap="gray")
# Out:
# Type: <class 'numpy.ndarray'>
# dtype: uint8
# shape: (303, 384)

# %%
coins
# Out:
# array([[ 47, 123, 133, ...,  14,   3,  12],
#        [ 93, 144, 145, ...,  12,   7,   7],
#        [126, 147, 143, ...,   2,  13,   3],
#        ...,
#        [ 81,  79,  74, ...,   6,   4,   7],
#        [ 88,  82,  74, ...,   5,   7,   8],
#        [ 91,  79,  68, ...,   4,  10,   7]], dtype=uint8)

# %%
coins.ndim
# Out:
# 2

# %% [markdown]
# #### A color image is a 3D array, where the last dimension has size 3 and represents the red, green, and blue channels

# %%
cat = data.chelsea()
print("Shape:", cat.shape)
print("Values min/max:", cat.min(), cat.max())

plt.imshow(cat)
# Out:
# Shape: (300, 451, 3)
# Values min/max: 0 231

# %%
cat
# Out:
# array([[[143, 120, 104],
#         [143, 120, 104],
#         [141, 118, 102],
#         ...,
#         [ 45,  27,  13],
#         [ 45,  27,  13],
#         [ 45,  27,  13]],
#
#        [[146, 123, 107],
#         [145, 122, 106],
#         [143, 120, 104],
#         ...,
#         [ 46,  29,  13],
#         [ 45,  29,  13],
#         [ 47,  30,  14]],
#
#        [[148, 126, 112],
#         [147, 125, 111],
#         [146, 122, 109],
#         ...,
#         [ 48,  28,  17],
#         [ 49,  29,  18],
#         [ 50,  30,  19]],
#
#        ...,
#
#        [[ 92,  58,  30],
#         [105,  71,  43],
#         [132,  98,  71],
#         ...,
#         [172, 145, 138],
#         [172, 145, 138],
#         [172, 145, 138]],
#
#        [[128,  92,  60],
#         [139, 103,  71],
#         [134,  95,  64],
#         ...,
#         [166, 142, 132],
#         [166, 142, 132],
#         [167, 143, 133]],
#
#        [[139, 103,  71],
#         [127,  88,  57],
#         [125,  86,  53],
# ...

# %%
cat.ndim
# Out:
# 3

# %%
cat[0]
# Out:
# array([[143, 120, 104],
#        [143, 120, 104],
#        [141, 118, 102],
#        ...,
#        [ 45,  27,  13],
#        [ 45,  27,  13],
#        [ 45,  27,  13]], dtype=uint8)

# %%
len(cat[0])
# Out:
# 451
